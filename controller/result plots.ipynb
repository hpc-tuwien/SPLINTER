# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the CSV file
file_path = '../experiment_progress_vgg16.csv'
data = pd.read_csv(file_path)

# %% [markdown]
# # Scheduling decision for VGG16

# %%
# Filter rows where the strategy is 'splinter:latency'
splinter_latency_data = data[data['strategy'] == 'splinter:latency'].copy()

# Add a new 'type' column based on the 'layer' column
splinter_latency_data['type'] = splinter_latency_data['layer'].apply(
    lambda x: 'cloud' if x == 0 else ('edge' if x == 22 else 'split')
)

# Count the occurrences of each type
type_counts = splinter_latency_data['type'].value_counts()


# Define font size variables
scale_fonts = 7
label_font_size = 14 + scale_fonts
title_font_size = 16 + scale_fonts
tick_font_size = 12 + scale_fonts
legend_font_size = 12 + scale_fonts
offset_font_size = 12 + scale_fonts


# Plotting a bar plot for the counts of each type
plt.figure(figsize=(5, 4))
type_counts.plot(kind='bar', color='tab:gray')
plt.xlabel("Splinter decision", fontsize=label_font_size)
plt.ylabel("Number of Requests",  fontsize=label_font_size)
plt.xticks(rotation=0)
plt.tick_params(axis='both', labelsize=tick_font_size)
plt.tight_layout()
plt.show()
